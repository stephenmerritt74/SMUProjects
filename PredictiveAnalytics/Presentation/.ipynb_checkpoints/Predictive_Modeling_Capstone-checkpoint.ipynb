# %% [markdown]
# ## Cluster Analysis for Store Formats

# %% [markdown]
# A company, currently comprised of 85 grocery stores, is looking to expand operations and open 10 new stores. With the opening of these new stores, the company is looking to diversify store formats to reduce product surpluses and shortages. Utilizing **Alteryx**, we will first perform cluster analysis to determine the optimal number of new store formats based on existing store sales percentages of the following categories: *Bakery, Deli, Frozen Food, Meat, Dry Grocery, General Merchandise, Dairy, Produce,* and *Dairy*.

# %% [markdown]
# Based on the aforementioned Cluster analysis using K-Means, the optimal number of new store formats is 3. We see below in figure 1-1 that the Median value of both the Adjusted Rand and Calinski-Harabasz indices are highest at 3.

# %%
#FIGURE 1-1
from IPython.display import Image
Image(filename='/Users/Steve/SMUProjects/PredictiveAnalytics/Graphics/Fig 1-1.jpg', width = 400, height = 400)

# %% [markdown]
# As can be seen in table 1-1 below, the new store formats are relatively balanced with 23 stores in format 1, 29 stores in format 1, and 33 stores in format 3.

# %%
#TABLE 1-1
Image(filename='/Users/Steve/SMUProjects/PredictiveAnalytics/Graphics/Table 1-1.PNG', width = 200, height = 200)

# %% [markdown]
# As can be seen below in Figure 1-2, we can see the most variation between the clustered store formats in the following Percentage of Sales in the following categories: *Bakery*, *Floral*, *General Merchandise*, and *Meat*
#
# Format 1 has the highest percentage of General Merchandise sales of all the store formats where Format 3 has the highest percentage of Meat sales. Format 2 has the highest percentage of both Bakery and Floral sales.

# %%
#FIGURE 1-2
Image(filename='/Users/Steve/SMUProjects/PredictiveAnalytics/Graphics/Fig 1-2_1.PNG', width = 200, height = 200)

# %%
#FIGURE 1-2
Image(filename='/Users/Steve/SMUProjects/PredictiveAnalytics/Graphics/Fig 1-2.PNG', width = 200, height = 200)

# %%
# %%HTML
# #You have to download this file and run the cell to view the visualization in Tableau Public
# <div class='tableauPlaceholder' id='viz1542118404525' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ca&#47;Capstone_Cluster&#47;ClusterMap&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Capstone_Cluster&#47;ClusterMap' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ca&#47;Capstone_Cluster&#47;ClusterMap&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1542118404525');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# #You have to download this file and run the cell to view the visualization in Tableau Public
# ...

# %%
#Cluster Map rending from Tableau Public link above.
Image(filename='/Users/Steve/SMUProjects/PredictiveAnalytics/Graphics/Fig 1-4.PNG', width = 600, height = 600)

# %%
#FIGURE 1-4
Image(filename='/Users/Steve/SMUProjects/PredictiveAnalytics/Graphics/Capstone_Model_1.PNG', width = 700, height = 700)

# %% [markdown]
# ## Classification Modeling for Store Format Assignment

# %% [markdown]
# Now that we have determined the optimal number of store formats, we’ll look to assign these formats to the 10 new stores. We’ll look at three different modeling techniques to assign formats to the new stores comparing demographic data of our existing stores to the demographic data of the new stores. Since this is a non-binary classification problem, the modeling techniques we’ll compare are a Decision Tree, Forest Model, and Boosted Model. While the accuracy scores of each model are very close, the **Boosted Model** has a far superior F1 statistic, so the Boosted Model is chosen. Please see Table 2-1 for performance comparison of the three models.

# %%
Image(filename='/Users/Steve/SMUProjects/PredictiveAnalytics/Graphics/Figure 2-3.PNG', width = 400, height = 400)

# %% [markdown]
# As can be seen below in Figure 2-1, the Boosted Model needs approximately 1700 iterations to find the optimal solution. Age0to9, HVal750KPlus, and EdHSGrad are the most important demographic data needed to classify the 10 new stores into the new formats.

# %%
Image(filename='/Users/Steve/SMUProjects/PredictiveAnalytics/Graphics/Figure 2-1.PNG', width = 300, height = 300)

# %% [markdown]
# Table 2-2 displays the classification of the new stores and their formats.
#
# | Store Number | Format |
# | ------------ | ------ |
# |    S0086     |   3    |
# |    S0087     |   2    |
# |    S0088     |   1    |
# |    S0089     |   2    |
# |    S0090     |   2    |
# |    S0091     |   1    |
# |    S0092     |   2    |
# |    S0093     |   1    |
# |    S0094     |   2    |
# |    S0095     |   2    |

# %%
#FIGURE 1-4
Image(filename='/Users/Steve/SMUProjects/PredictiveAnalytics/Graphics/Capstone_Model2.PNG', width = 700, height = 700)

# %% [markdown]
# ## Time Series Modeling for Sales Forecasts

# %% [markdown]
# Finally, we will attempt to predict the produce sales for 2016 for both our 85 existing and 10 new stores. We’ll use time series analysis to make these predictions. As can be seen in Figure 3-1, the time series for produce sales is Seasonal, with no discernible trend, with an error term. We will use an ETS (M, N, M) non-dampened model, along with a Seasonal ARIMA(0,1,1)(0,1,1)[12] using 6 months of holdout data to compare forecasts and fit statistics.

# %%
Image(filename='/Users/Steve/SMUProjects/PredictiveAnalytics/Graphics/Fig 3-1.PNG', width = 500, height = 500)

# %%
Image(filename='/Users/Steve/SMUProjects/PredictiveAnalytics/Graphics/Fig 3-1_2.PNG', width = 700, height = 700)

# %%
Image(filename='/Users/Steve/SMUProjects/PredictiveAnalytics/Graphics/Fig 3-1_1.PNG', width = 500, height = 500)

# %% [markdown]
# After comparing the in-sample error measures for the different models, the fit statistics, and autocorrelation plots, the ETS(MNM) non-dampened Models is chosen to be most appropriate. The seasonal ARIMA(0, 1, 1)(0,1,1)[6] is close, but the plots in figure 3-2 above demonstrate that the ETS Model more closely models the 6-month holdout data. Also the RMSE for the ETS Model is lower at 760267.4 vs. 792197.3.

# %% [markdown]
# Utilizing the ETS(MNM) model, the final 2016 forecast numbers for both new and existing store produce sales can be found in Table 3-3 below.
#
# |    Month     |   New Stores     | Existing Stores |
# | ------------ | ----------------- | ----------------- |
# |    Jan - 16  |   2,587,450.86    |   21,539,936.01   |
# |    Feb - 16  |   2,477,352.90    |   20,413,770.60  |
# |    Mar - 16  |   2,913,185.24    |   24,325,953.10   |
# |    Apr - 16  |   2,775,745.61    |   22,993,466.35   |
# |    May - 16  |   3,150,866.84    |   26,691,951.42   |
# |    Jun - 16  |   3,188,922.01    |   26,989,964.01   |
# |    Jul - 16  |   3,214,745.65    |   26,948,630.76   |
# |    Aug - 16  |   2,866,348.67    |   24,091,579.35   |
# |    Sep - 16  |   2,538,726.85    |   20,523,492.41   |
# |    Oct - 16  |   2,488,148.29    |   20,011,748.67   |
# |    Nov - 16  |   2,595,270.39    |   21,177,435.49   |
# |    Dec - 16  |   2,573,396.63    |   20,855,799.11   |

# %%
Image(filename='/Users/Steve/SMUProjects/PredictiveAnalytics/Graphics/Capstone_Model3.PNG', width = 700, height = 700)

# %%
# %%HTML
# #You have to download this file and run the cell to view the visualization in Tableau Public
# <div class='tableauPlaceholder' id='viz1542118703228' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Sa&#47;Sales_Area_Chart&#47;Sales_Area&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Sales_Area_Chart&#47;Sales_Area' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Sa&#47;Sales_Area_Chart&#47;Sales_Area&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1542118703228');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# #You have to download this file and run the cell to view the visualization in Tableau Public
# ...

# %%
Image(filename='/Users/Steve/SMUProjects/PredictiveAnalytics/Graphics/Figure 3-1.PNG', width = 400, height = 400)
